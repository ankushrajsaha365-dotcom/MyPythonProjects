# %%
num = int(input("Enter range:"))

for i in range(1, num + 1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
num = int(input("Enter range:"))

for i in range(1, num + 1):
    for j in range(1,i+1):
        print("*",end=" ")
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
