# %% [markdown]
# ## ❌ Wrong
# __s = {}__
#
# ## ✅ Correct
# __s = set()__

# %%
s = set(map(int, input("Enter elements: ").split()))
print(s)
# Out:
# set()

# %%
s = set(input().split())
print(s)
# Out:
# {'gfdg', 'er6w', '4356', 'w346'}

# %%
n = int(input("Enter number of elements: "))
s = set()

for _ in range(n):
    x = int(input("Enter element: "))
    s.add(x)

print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Taking character set from a string
s = set(input("Enter string: "))
print(s)
# Out:
# {'g', 'd', 'f', 's'}
