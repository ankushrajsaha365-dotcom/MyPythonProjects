# %% [markdown]
# #  Sets
#
# - **Unordered**, **mutable** collection of **unique elements**
# - Does **not allow duplicates**
# - Elements can be of **different types**, but **must be hashable**
# - Useful for **membership tests**, **removing duplicates**, and **set operations**

# %% [markdown]
# ### Set Methods

# %%
s = {13,24,56}
s.add(68)
print(s)

s.remove(24)
print(s)
# Out:
# {24, 56, 68, 13}
# {56, 68, 13}

# %%
s = {13,24,56}
try:
    s.remove(34)
    print(s)
raise ValueError("raises error if not found")
s.discard(34)
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 s = {13,24,56}
# ----> 2 s.remove(34)
#       3 print(s)
#       5 s.discaer(34)
#
# KeyError: 34
