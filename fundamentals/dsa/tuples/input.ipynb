# %%
t = tuple(input().split())
print(t)

## Returns strings
# Out:
# ('3', '3', '5', '7', '8')

# %%
t = tuple(map(int, input().split()))            #Type casting into integer
print(t)
# Out:
# (12, 243, 45645, 58)

# %%
n = int(input("How many elements?"))                # User defined number of elements
t = tuple(input() for _ in range(n))
print(t)
# Out:
# ('1', '2', '3', '43', '5')

# %%
# Letting user enter a tuple literally (advanced, careful)
# User types:
# (1, 2, 3)

tup = eval(input())
print(tup)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 8)
