# %% [markdown]
# 🔹 1️⃣ __len()__
#
# Returns number of elements.
#
# __Works on:__
# - list
# - tuple
# - string
# - dictionary
# - set

# %%
nums = [10, 20, 30]
print(len(nums))   # 3
# Out:
# 3

# %% [markdown]
# 🔹 2️⃣ ____type()__
#
# Tells you the datatype.
#
# - Useful for debugging

# %%
x = 10
print(type(x))  # <class 'int'>
# Out:
# <class 'int'>

# %% [markdown]
# 🔹 3️⃣ __range()__
#
# Generates a sequence of numbers.
#
# __Forms__
#
# - range(stop)
# - range(start, stop)
# - range(start, stop, step)

# %%
print(list(range(5)))
# [0, 1, 2, 3, 4]

print(list(range(1, 10, 2)))
# [1, 3, 5, 7, 9]
# Out:
# [0, 1, 2, 3, 4]
# [1, 3, 5, 7, 9]

# %% [markdown]
# 🔹 4️⃣ __sum()__
#
# Adds iterable elements.

# %%
nums = [1,2,3,4]

print(sum(nums))  # 10

print(sum(nums,25)) # 35
# Out:
# 10
# 35

# %% [markdown]
# 🔹 5️⃣ __min() and max()__

# %%
nums = [5, 2, 9, 1]

print(min(nums))  # 1
print(max(nums))  # 9
print(min("raj"))  # 'a'   # works on strings too
# Out:
# 1
# 9
# a

# %% [markdown]
# 🔹 6️⃣ __abs()__
#
# Absolute value.

# %%
print(abs(-10))  # 10
# Out:
# 10

# %% [markdown]
# 🔹 7️⃣ __round()__
#
# Rounds number.

# %%
print(round(3.14159, 2))  # 3.14
# Out:
# 3.14

# %% [markdown]
# 🔹 8️⃣ __sorted()__
#
# Returns new sorted list.
#
# Important:
# - sorted() does NOT modify original list.

# %%
nums = [4, 1, 3, 2]
print(sorted(nums))             # By default ascending

print(sorted(nums, reverse=True))   # descending
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %% [markdown]
# 🔹 9️⃣ __enumerate()__
#
# Gives index + value.

# %%
names = ["Raj", "Aman", "Riya"]

for index, name in enumerate(names):
    print(index, name)

print("________")

for index, name in enumerate(names, start = 1):         # custom start
    print(index, name)
# Out:
# 0 Raj
# 1 Aman
# 2 Riya
# ________
# 1 Raj
# 2 Aman
# 3 Riya

# %% [markdown]
# 🔹 🔟 __zip()__
#
# Combines multiple iterables.

# %%
names = ["Raj", "Aman"]
marks = [85, 92]

print(list(zip(names, marks)))
# [('Raj', 85), ('Aman', 92)]
# Out:
# [('Raj', 85), ('Aman', 92)]

# %% [markdown]
# 🔹 1️⃣1️⃣ __all() and any()__
#
# - all() → True if ALL elements are True
# - any() → True if ANY element is True

# %%
print(all([True, True, False]))  # False
print(any([False, False, True]))  # True


# Very useful in conditions.
# Out:
# False
# True
