# %%
import numpy as np

a = np.array([12,23,45])
b = np.array([89,26,11])

sum_arr = a+b
prod_arr = a*b

print(sum_arr)
# Out:
# [101  49  56]

# %%
print(np.sum(a))
print(np.mean(a))
print(np.std(a))
# Out:
# 80
# 26.666666666666668
# 13.719410418171119

# %%
data = np.random.randint(1,100,10)

# Find maximum, minimum, and average
max_val = np.max(data)
min_val = np.min(data)
avg_val = np.mean(data)

print(max_val)
# Out:
# 78
